# %%
import pandas as pd
import numpy as np
 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style="darkgrid")

from scipy.stats import percentileofscore
from scipy import stats

import pymc3 as pm
import arviz as az

# pd.set_option('display.max_columns', None)

from utils import *

# %load_ext autoreload
# %autoreload 2

import warnings
warnings.filterwarnings("ignore")
# Out:
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
import scipy.stats as scs
from scipy.stats import norm
import math
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

from sklearn.preprocessing import StandardScaler
from sklearn import linear_model

# %% [markdown]
# ### Business Idea: How Much Each Channel contribute to the Target?

# %% [markdown]
# #### Loading Data

# %%
data = pd.read_excel('data/bet_awards_modfile_FINAL_08.23.2021.xlsx')
data.head()
# Out:
#    dma_code  cplx_imp_i  smsn_imp_i  spot_imp_i  vzio_imp_i  tw_imp_i  \
# 0     500.0    0.008422    0.015025    0.212211    0.013772  0.348791
# 1     501.0    0.016431    0.036270    0.225445    0.007491  0.369489
# 2     502.0    0.006553    0.015509    0.178028    0.011686  0.344432
# 3     503.0    0.010626    0.017485    0.119478    0.013206  0.353738
# 4     504.0    0.016560    0.025442    0.204707    0.010759  0.370823
#
#    fb_imp_i  yt_imp_i  tv_exp_i  tune_in_i
# 0  0.023189  0.119566  0.005713   0.050437
# 1  0.046153  0.184742  0.010343   0.097058
# 2  0.037104  0.141722  0.008395   0.132308
# 3  0.095669  0.236077  0.022665   0.223991
# 4  0.046618  0.321395  0.015143   0.130586

# %%
# dma_code column assigned to region and can be dropped
data = data.drop(columns=['dma_code'])
# checking for Nan values in columns
data.isna().sum().sum()
# Out:
# 0

# %%
data.describe()
# Out:
#        cplx_imp_i  smsn_imp_i  spot_imp_i  vzio_imp_i    tw_imp_i    fb_imp_i  \
# count  210.000000  210.000000  210.000000  210.000000  210.000000  210.000000
# mean     0.008516    0.021490    0.180836    0.013638    0.352482    0.050132
# std      0.003937    0.008625    0.052792    0.009866    0.010691    0.018990
# min      0.001626    0.008018    0.074963    0.007491    0.334246    0.000000
# 25%      0.005782    0.015603    0.147842    0.011492    0.344670    0.037052
# 50%      0.007491    0.020142    0.172508    0.012958    0.350286    0.046479
# 75%      0.010398    0.025903    0.211144    0.014160    0.357436    0.057383
# max      0.022324    0.058665    0.368853    0.150939    0.401953    0.139827
#
#          yt_imp_i    tv_exp_i   tune_in_i
# count  210.000000  210.000000  210.000000
# mean     0.175388    0.010169    0.091919
# std      0.059557    0.004788    0.054194
# min      0.071617    0.001961    0.000000
# 25%      0.138629    0.006756    0.056087
# 50%      0.161186    0.009065    0.083639
# 75%      0.195522    0.011949    0.119984
# max      0.434015    0.024520    0.250879

# %%
# Distribution of the target variable
target_distribution(data.tune_in_i)

# %% [markdown]
# #### As we can tell Target variable is aproximatly Normally Distributed with mean = 0.09 and median = 0.08. As mean < median we observe right skewness

# %% [markdown]
# ### Relationship between independent and dependent variable

# %% [markdown]
# ### Check for Multicolinearity between independent variables

# %%
features_corr_matrix(data.iloc[:,:-1], 0.8, matrix= True)
# Out:
# Based on threshold 0.8 , sugested featrures to drop - ['cplx_imp_i', 'tw_imp_i']
#             cplx_imp_i  tw_imp_i
# cplx_imp_i    1.000000  0.812304
# tw_imp_i      0.812304  1.000000

# %%
plot_relationship(data.iloc[:,:-1], data.tune_in_i)

# %% [markdown]
# ## Building Multiple Bayesian Linear Model with pyMC3

# %%
x = data.iloc[:,:-1].values
y = data.tune_in_i.values

# %%
with pm.Model() as model_mlr_normal:
    
    # Intercept
    alpha = pm.Normal('alpha', mu=0, sd=25)
    # Slope
    beta = pm.Normal('beta', mu=0, sd=25, shape= len(data.columns[:-1]))
    # Error term
    eps = pm.HalfCauchy('eps', 25)
    # Expected value of outcome (MLR with vectors)
    mu =  alpha + pm.math.dot(x, beta)
    # Likelihood
    tune_in_i = pm.Normal('tune_in_i', mu= mu, sd= eps, observed= y)
    
    # posterior/create the race
    trace_mlr_normal = pm.sample(chains= 4, target_accept = 0.9)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 2 jobs)
# NUTS: [eps, beta, alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 03:55<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 286 seconds.

# %% [markdown]
# ### Sample prior predictive check

# %%
az.plot_trace(trace_normal)
plt.show()

# %%
# Lets look at intercepts
varnames = ['alpha', 'eps', 'beta']
az.summary(trace_mlr_normal, var_names = varnames[-1]).set_index(data.columns[:-1])
# Out:
#              mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# cplx_imp_i  2.379  0.773   0.806    3.723      0.017    0.012    2032.0
# smsn_imp_i -0.285  0.241  -0.767    0.147      0.004    0.003    3241.0
# spot_imp_i -0.158  0.057  -0.266   -0.051      0.001    0.001    2424.0
# vzio_imp_i  0.240  0.162  -0.048    0.561      0.003    0.002    4018.0
# tw_imp_i    0.298  0.286  -0.235    0.822      0.007    0.005    1729.0
# fb_imp_i    0.117  0.142  -0.139    0.383      0.003    0.002    3023.0
# yt_imp_i   -0.079  0.047  -0.165    0.010      0.001    0.001    3072.0
# tv_exp_i    9.033  0.638   7.912   10.270      0.013    0.009    2458.0
#
#             ess_tail  r_hat
# cplx_imp_i    2653.0    1.0
# smsn_imp_i    2537.0    1.0
# spot_imp_i    2655.0    1.0
# vzio_imp_i    2731.0    1.0
# tw_imp_i      2160.0    1.0
# fb_imp_i      2794.0    1.0
# yt_imp_i      2692.0    1.0
# tv_exp_i      2988.0    1.0

# %%
# Lets look at the slope and error
az.summary(trace_mlr_normal, var_names = varnames[:-1])
# Out:
#         mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# alpha -0.086  0.093  -0.261    0.085      0.002    0.002    1697.0    2066.0
# eps    0.022  0.001   0.020    0.025      0.000    0.000    3675.0    2324.0
#
#        r_hat
# alpha    1.0
# eps      1.0

# %%
plot_correlation(trace_normal, data)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-52-6ce5fbb96151> in <module>
# ----> 1 plot_correlation(trace_normal, data)
#
# ~\Documents\Bet_Awards\utils.py in plot_correlation(trace, data)
#     255         else:
#     256             j=1
# --> 257             sns.scatterplot('alpha', col, data=df, ax=axes[j,k]);
#     258             k+=1
#     259
#
# IndexError: index 4 is out of bounds for axis 1 with size 4

# %%
check_rhat(trace_normal, 1.01)
# Out:
# The following parameters have an Rhat greater 1.01:

# %%
# az.plot_pair(trace_normal, kind ='kde', fill_last= False)

# %%
az.plot_energy(trace_normal)
plt.show()

# %%
## Look for predictions using posterior
ppc_normal = pm.sample_posterior_predictive(trace_normal, samples=100, model = model_mlr_normal)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='100' class='' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [100/100 00
ax = az.plot_ppc(data_ppc, figsize=(8,4), mean= True, color='C0')
ax.legend(fontsize= 15)
plt.show()
# Out:
# posterior predictive variable tune_in_i's shape not compatible with number of chains and draws. This can mean that some draws or even whole chains are not represented.

# %%
plt.figure(figsize=(10, 5))
ppc_data = [y, 
            ppc_normal['tune_in_i'], 
           ]

labels = ['data', 'Normal']
for i, d in enumerate(ppc_data):
    mean = d.mean()
    err = np.percentile(d, [25, 75])
    plt.errorbar(mean, -i, xerr=[[-err[0]], [err[1]]], fmt='o')
    plt.text(mean, -i+0.2, labels[i], ha='center', fontsize=14)
    plt.ylim([-i-0.5, 0.5])
    plt.xlim([-0.25, 0.75])
    plt.yticks([])

# %% [markdown]
# # GLM

# %%
# Formula for Bayesian Linear Regression (follows R formula syntax
formula = 'tune_in_i ~ ' + ' + '.join(['%s' % variable for variable in data.columns[:-1]])
formula
# Out:
# 'tune_in_i ~ cplx_imp_i + smsn_imp_i + spot_imp_i + vzio_imp_i + tw_imp_i + fb_imp_i + yt_imp_i + tv_exp_i'

# %%
# Context for the model
with pm.Model() as normal_model_glm:
    
    # The prior for the model parameters will be a normal distribution
    family = pm.glm.families.Normal()
    
    # Creating the model requires a formula and data (and optionally a family)
    pm.GLM.from_formula(formula, data = data, family = family)
    
    # Perform Markov Chain Monte Carlo sampling
    normal_trace_glm = pm.sample(chains = 4, target_accept = 0.9)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 2 jobs)
# NUTS: [sd, tv_exp_i, yt_imp_i, fb_imp_i, tw_imp_i, vzio_imp_i, spot_imp_i, smsn_imp_i, cplx_imp_i, Intercept]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 05:06<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 353 seconds.

# %%
var_names = normal_trace.varnames
print(var_names)
# Out:
# ['Intercept', 'cplx_imp_i', 'smsn_imp_i', 'spot_imp_i', 'vzio_imp_i', 'tw_imp_i', 'fb_imp_i', 'yt_imp_i', 'tv_exp_i', 'sd_log__', 'sd']

# %%
az.plot_trace(normal_trace)
plt.show()

# %%
az.summary(normal_trace, var_names = var_names[1:-2]).set_index(data.columns[:-1])
# Out:
#              mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# cplx_imp_i  2.354  0.795   0.823    3.821      0.015    0.011    2822.0
# smsn_imp_i -0.290  0.244  -0.719    0.180      0.004    0.003    3497.0
# spot_imp_i -0.154  0.059  -0.270   -0.045      0.001    0.001    2839.0
# vzio_imp_i  0.238  0.168  -0.074    0.547      0.003    0.002    3677.0
# tw_imp_i    0.295  0.295  -0.296    0.808      0.006    0.005    2427.0
# fb_imp_i    0.120  0.144  -0.138    0.409      0.003    0.002    2442.0
# yt_imp_i   -0.080  0.048  -0.164    0.012      0.001    0.001    3007.0
# tv_exp_i    9.063  0.674   7.749   10.292      0.014    0.010    2496.0
#
#             ess_tail  r_hat
# cplx_imp_i    2562.0    1.0
# smsn_imp_i    2730.0    1.0
# spot_imp_i    2250.0    1.0
# vzio_imp_i    2362.0    1.0
# tw_imp_i      2447.0    1.0
# fb_imp_i      2444.0    1.0
# yt_imp_i      2358.0    1.0
# tv_exp_i      2069.0    1.0
