# %%
import pandas as pd
import numpy as np
 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style="darkgrid")

from scipy.stats import percentileofscore
from scipy import stats

import pymc3 as pm
import arviz as az

# pd.set_option('display.max_columns', None)

from utils import *

# %load_ext autoreload
# %autoreload 2

import warnings
warnings.filterwarnings("ignore")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import scipy.stats as scs
from scipy.stats import norm
import math
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

from sklearn.preprocessing import StandardScaler
from sklearn import linear_model

# %% [markdown]
# ### Business Idea: What Media Channel Is mostly Contribute to the Target?

# %% [markdown]
# #### Loading Data

# %%
data = pd.read_excel('data/bet_awards_modfile_FINAL_08.23.2021.xlsx')
data.head()
# Out:
#    dma_code  cplx_imp_i  smsn_imp_i  spot_imp_i  vzio_imp_i  tw_imp_i  \
# 0     500.0    0.008422    0.015025    0.212211    0.013772  0.348791
# 1     501.0    0.016431    0.036270    0.225445    0.007491  0.369489
# 2     502.0    0.006553    0.015509    0.178028    0.011686  0.344432
# 3     503.0    0.010626    0.017485    0.119478    0.013206  0.353738
# 4     504.0    0.016560    0.025442    0.204707    0.010759  0.370823
#
#    fb_imp_i  yt_imp_i  tv_exp_i  tune_in_i
# 0  0.023189  0.119566  0.005713   0.050437
# 1  0.046153  0.184742  0.010343   0.097058
# 2  0.037104  0.141722  0.008395   0.132308
# 3  0.095669  0.236077  0.022665   0.223991
# 4  0.046618  0.321395  0.015143   0.130586

# %%
# dma_code column assigned to region and can be dropped
data = data.drop(columns=['dma_code'])
# checking for Nan values in columns
data.isna().sum().sum()
# Out:
# 0

# %%
data.describe()
# Out:
#        cplx_imp_i  smsn_imp_i  spot_imp_i  vzio_imp_i    tw_imp_i    fb_imp_i  \
# count  210.000000  210.000000  210.000000  210.000000  210.000000  210.000000
# mean     0.008516    0.021490    0.180836    0.013638    0.352482    0.050132
# std      0.003937    0.008625    0.052792    0.009866    0.010691    0.018990
# min      0.001626    0.008018    0.074963    0.007491    0.334246    0.000000
# 25%      0.005782    0.015603    0.147842    0.011492    0.344670    0.037052
# 50%      0.007491    0.020142    0.172508    0.012958    0.350286    0.046479
# 75%      0.010398    0.025903    0.211144    0.014160    0.357436    0.057383
# max      0.022324    0.058665    0.368853    0.150939    0.401953    0.139827
#
#          yt_imp_i    tv_exp_i   tune_in_i
# count  210.000000  210.000000  210.000000
# mean     0.175388    0.010169    0.091919
# std      0.059557    0.004788    0.054194
# min      0.071617    0.001961    0.000000
# 25%      0.138629    0.006756    0.056087
# 50%      0.161186    0.009065    0.083639
# 75%      0.195522    0.011949    0.119984
# max      0.434015    0.024520    0.250879

# %%
# Distribution of the target variable
target_distribution(data.tune_in_i)

# %% [markdown]
# #### As we can tell Target variable is aproximatly Normally Distributed with mean = 0.09 and median = 0.08. As mean < median we observe right skewness

# %% [markdown]
# ### Relationship between independent and dependent variable

# %%
plot_relationship(data.iloc[:,:-1],data.tune_in_i)

# %% [markdown]
# ### Check for Multicolinearity between independent variables

# %%
features_corr_matrix(data.iloc[:,:-1], 0.8, matrix= True)
# Out:
# Based on threshold 0.8 , sugested featrures to drop - ['cplx_imp_i', 'tw_imp_i']
#             cplx_imp_i  tw_imp_i
# cplx_imp_i    1.000000  0.812304
# tw_imp_i      0.812304  1.000000

# %%
x = data.iloc[:,:-1].values
y = data.tune_in_i.values

# %%
with pm.Model() as model_mlr_normal:
    
    # Intercept
    alpha = pm.Normal('alpha', mu=0, sd=25)
    # Slope
    beta = pm.Normal('beta', mu=0, sd=25, shape= len(data.columns[:-1]))
    # Error term
    eps = pm.HalfCauchy('eps', 25)
    # Expected value of outcome (MLR with vectors)
    mu =  alpha + pm.math.dot(x, beta)
    # Likelihood
    tune_in_i = pm.Normal('tune_in_i', mu= mu, sd= eps, observed= y)
    
    # posterior/create the race
    trace_normal = pm.sample(chains= 4)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 2 jobs)
# NUTS: [eps, beta, alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 02:58<00:00 Sampling 4 chains, 8 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 226 seconds.
# There were 2 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 4 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 2 divergences after tuning. Increase `target_accept` or reparameterize.

# %% [markdown]
# ### Sample prior predictive check

# %%
# with model_mlr_normal:
#     prior_pred = pm.sample_prior_predictive()

# %%
# fig,ax = plt.subplots(figsize= (12,8))
# ax.plot(prior_pred['tune_in_i'].T, color="0.5", alpha= .1)
# ax.set(ylim= (-10, 10),
#      xlim= (-10, 10),
#      title= "Prior predictive",
#      xlabel= 'tune_in_i')
# plt.show()

# %%
az.plot_trace(trace_normal)
plt.show()

# %%
# Lets look at intercepts
varnames = ['alpha', 'eps', 'beta']
az.summary(trace_normal, var_names = varnames[-1]).set_index(data.columns[:-1])
# Out:
#              mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# cplx_imp_i  2.241  0.605   1.062    3.322      0.011    0.008    2979.0
# smsn_imp_i -0.269  0.237  -0.732    0.154      0.004    0.003    3089.0
# spot_imp_i -0.259  0.056  -0.362   -0.154      0.001    0.001    2568.0
# vzio_imp_i  0.196  0.168  -0.110    0.528      0.003    0.002    3419.0
# tw_imp_i    0.683  0.271   0.183    1.202      0.006    0.004    2071.0
# fb_imp_i    0.370  0.144   0.074    0.616      0.004    0.003    1289.0
# yt_imp_i   -0.022  0.048  -0.112    0.068      0.001    0.001    3354.0
# tv_exp_i    6.561  0.587   5.503    7.670      0.015    0.011    1395.0
#
#             ess_tail  r_hat
# cplx_imp_i    2745.0    1.0
# smsn_imp_i    2610.0    1.0
# spot_imp_i    2498.0    1.0
# vzio_imp_i    2717.0    1.0
# tw_imp_i      2541.0    1.0
# fb_imp_i       367.0    1.0
# yt_imp_i      2787.0    1.0
# tv_exp_i       787.0    1.0

# %%
# Lets look at the slope and error
az.summary(trace_normal, var_names = varnames[:-1])
# Out:
#         mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# alpha -0.200  0.088  -0.363   -0.034      0.002    0.001    2090.0    2575.0
# eps    0.023  0.001   0.021    0.026      0.000    0.000     950.0     375.0
#
#        r_hat
# alpha    1.0
# eps      1.0

# %%
#plot_correlation(trace_normal, data)

# %%
check_rhat(trace_normal, 1.01)
# Out:
# The following parameters have an Rhat greater 1.01:

# %%
# az.plot_pair(trace_normal, kind ='kde', fill_last= False)

# %%
az.plot_energy(trace_normal)
plt.show()

# %%
## Look for predictions using posterior
ppc_normal = pm.sample_posterior_predictive(trace_normal, samples=100, model = model_mlr_normal)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='100' class='' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [100/100 00:00<00:00]
#     </div>

# %%
results_normal = pd.DataFrame(ppc_normal['tune_in_i']).T
results_normal
# Out:
#            0         1         2         3         4         5         6   \
# 0    0.048790  0.061882  0.054814  0.038193  0.039621  0.037978  0.047649
# 1    0.106918  0.117119  0.084964  0.105323  0.095142  0.096247  0.035166
# 2    0.118034  0.047040  0.075873  0.085097  0.033748  0.083511  0.072388
# 3    0.224730  0.206833  0.240508  0.211954  0.205104  0.290558  0.197139
# 4    0.188392  0.173324  0.115277  0.165477  0.146923  0.084272  0.157100
# ..        ...       ...       ...       ...       ...       ...       ...
# 205  0.017882  0.043741  0.057598  0.065949  0.088365 -0.006024 -0.010892
# 206  0.065681  0.032923  0.081562  0.051504  0.041264  0.044100  0.064434
# 207  0.012646  0.057116  0.029225  0.069707  0.100076  0.045275  0.055116
# 208  0.060524  0.029959  0.078312  0.046026  0.018109  0.052322  0.102285
# 209  0.037700  0.019493  0.054078  0.051713  0.044572  0.012062  0.043395
#
#            7         8         9   ...        90        91        92  \
# 0    0.041505  0.069844  0.065877  ...  0.038767  0.057316  0.032645
# 1    0.143468  0.113125  0.108388  ...  0.110616  0.128782  0.109892
# 2    0.082168  0.059495  0.062802  ...  0.047598  0.090593  0.070716
# 3    0.220002  0.190208  0.199371  ...  0.225449  0.228589  0.184542
# 4    0.165473  0.156021  0.162481  ...  0.143499  0.172453  0.113321
# ..        ...       ...       ...  ...       ...       ...       ...
# 205  0.072926  0.032647  0.056464  ...  0.009304  0.006415  0.053246
# 206  0.081329  0.058296  0.051067  ...  0.072929  0.079593  0.067514
# 207  0.113098  0.094386  0.071592  ...  0.067049  0.095549  0.036690
# 208  0.039083  0.047516  0.022000  ...  0.108558  0.059896  0.078314
# 209  0.016363  0.034091  0.055650  ...  0.060708  0.058914  0.074122
#
#            93        94        95        96        97        98        99
# 0    0.037288  0.050692  0.069787  0.046812  0.067559  0.060137  0.019079
# 1    0.117312  0.083483  0.130431  0.105034  0.124378  0.115140  0.086355
# 2    0.056540  0.076200  0.064486  0.074796  0.015171  0.076980  0.073333
# 3    0.220753  0.191507  0.200536  0.180460  0.176097  0.207017  0.227998
# 4    0.154306  0.152647  0.137646  0.169441  0.099269  0.121959  0.110116
# ..        ...       ...       ...       ...       ...       ...       ...
# 205  0.005684  0.039684  0.009660  0.074256  0.098621  0.028133  0.047357
# 206  0.063220  0.071511  0.090538  0.079614  0.067973  0.097140  0.093896
# 207  0.049121  0.085602  0.052357  0.033566  0.084008  0.066310  0.086353
# 208  0.049184  0.010833  0.025629  0.040844  0.034945  0.081529  0.041674
# 209  0.063788  0.042293  0.050951  0.042687  0.042119  0.057854  0.033080
#
# [210 rows x 100 columns]

# %%
data_ppc = az.from_pymc3(trace= trace_normal, posterior_predictive= ppc_normal)
ax = az.plot_ppc(data_ppc, figsize=(16,6), mean= True, color='C0')
ax.legend(fontsize= 15)
plt.show()
# Out:
# posterior predictive variable tune_in_i's shape not compatible with number of chains and draws. This can mean that some draws or even whole chains are not represented.

# %%
plt.figure(figsize=(10, 5))
ppc_data = [y, 
            ppc_normal['tune_in_i'], 
           ]

labels = ['data', 'Normal']
for i, d in enumerate(ppc_data):
    mean = d.mean()
    err = np.percentile(d, [25, 75])
    plt.errorbar(mean, -i, xerr=[[-err[0]], [err[1]]], fmt='o')
    plt.text(mean, -i+0.2, labels[i], ha='center', fontsize=14)
    plt.ylim([-i-0.5, 0.5])
    plt.xlim([-0.25, 0.75])
    plt.yticks([])

# %%
data_ppc = az.from_pymc3(trace= trace_normal, posterior_predictive= ppc_normal)
ax = az.plot_ppc(data_ppc, figsize=(16,6), mean= True, color='C0')
ax.legend(fontsize= 15)
plt.show()
# Out:
# posterior predictive variable tune_in_i's shape not compatible with number of chains and draws. This can mean that some draws or even whole chains are not represented.

# %% [markdown]
# # GLM

# %%
model_formula = 'Conver = '
for variable in normal_trace_normal.varnames:
    model_formula += ' %0.2f * %s +' % (np.mean(normal_trace_normal[variable]), variable)
' '.join(model_formula.split(' ')[:-1])

# %%
with Model() as model: # model specifications in PyMC3 are wrapped in a with-statement
    # Define priors
    sigma = HalfCauchy('sigma', beta=10, testval=1.)
    intercept = Normal('Intercept', 0, sd=20)
    x_coeff = Normal('x', 0, sd=20)
    
    # Define likelihood
    likelihood = Normal('y', mu=intercept + x_coeff * x, 
                        sd=sigma, observed=y)
    
    # Inference!
    trace = sample() # draw posterior samples using NUTS sampling
